# %% [markdown]
# The code below to helps analyze the data returned by the MBTA API:

# %%
mbtaURL = "https://api-v3.mbta.com/vehicles?filter[route]=1&include=trip"

import urllib.request, json
with urllib.request.urlopen(mbtaURL) as url:
    data = json.loads(url.read().decode())
   
    with open('data.json', 'w') as outfile:
        json.dump(data, outfile)
   
    with open('data.txt', 'w') as outfile:
        json.dump(json.dumps(data, indent=4, sort_keys=True), outfile)
       
    print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "data": [
#         {
#             "attributes": {
#                 "bearing": 156,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 12,
#                 "direction_id": 1,
#                 "label": "1895",
#                 "latitude": 42.348691919,
#                 "longitude": -71.08850973,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "speed": null,
#                 "updated_at": "2022-11-02T19:04:48-04:00"
#             },
#             "id": "y1895",
#             "links": {
#                 "self": "/vehicles/y1895"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "79",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "53316384",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 0,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 1,
#                 "direction_id": 1,
#                 "label": "1893",
#                 "latitude": 42.33015,
#                 "longitude": -71.08322,
#                 "occupancy_status": null,
#                 "speed": null,
#                 "updated_at": "2022-11-02T19:04:35-04:00"
#             },
#             "id": "y1893",
#             "links": {
#                 "self": "/vehicles/y1893"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "17863",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "53315099",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 48,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 15,
#                 "direction_id": 0,
#                 "label": "1865",
#                 "latitude": 42.35941672,
#                 "longitude": -71.09394713,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "speed": null,
#                 "updated_at": "2022-11-02T19:04:51-04:00"
#             },
#             "id": "y1865",
#             "links": {
#                 "self": "/vehicles/y1865"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "97",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "53314350",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 340,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 12,
#                 "direction_id": 0,
#                 "label": "1864",
#                 "latitude": 42.34440795,
#                 "longitude": -71.08629809,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "speed": null,
#                 "updated_at": "2022-11-02T19:04:52-04:00"
#             },
#             "id": "y1864",
#             "links": {
#                 "self": "/vehicles/y1864"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "91",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "53315859",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 0,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 16,
#                 "direction_id": 0,
#                 "label": "1863",
#                 "latitude": 42.360448249,
#                 "longitude": -71.095218399,
#                 "occupancy_status": "FULL",
#                 "speed": null,
#                 "updated_at": "2022-11-02T19:04:44-04:00"
#             },
#             "id": "y1863",
#             "links": {
#                 "self": "/vehicles/y1863"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "99",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "53315403",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 0,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 15,
#                 "direction_id": 1,
#                 "label": "1855",
#                 "latitude": 42.34161155,
#                 "longitude": -71.08317694,
#                 "occupancy_status": "FULL",
#                 "speed": null,
#                 "updated_at": "2022-11-02T19:04:52-04:00"
#             },
#             "id": "y1855",
#             "links": {
#                 "self": "/vehicles/y1855"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "187",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "53314636",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 168,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 13,
#                 "direction_id": 1,
#                 "label": "1812",
#                 "latitude": 42.34557721,
#                 "longitude": -71.08683666,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "speed": null,
#                 "updated_at": "2022-11-02T19:04:50-04:00"
#             },
#             "id": "y1812",
#             "links": {
#                 "self": "/vehicles/y1812"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "80",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "53314959",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 0,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 1,
#                 "direction_id": 0,
#                 "label": "1794",
#                 "latitude": 42.37302722,
#                 "longitude": -71.11739083,
#                 "occupancy_status": "FEW_SEATS_AVAILABLE",
#                 "speed": null,
#                 "updated_at": "2022-11-02T19:04:48-04:00"
#             },
#             "id": "y1794",
#             "links": {
#                 "self": "/vehicles/y1794"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "110",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "53314688",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 0,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 1,
#                 "direction_id": 1,
#                 "label": "1776",
#                 "latitude": 42.3298,
#                 "longitude": -71.08349,
#                 "occupancy_status": null,
#                 "speed": null,
#                 "updated_at": "2022-11-02T19:04:35-04:00"
#             },
#             "id": "y1776",
#             "links": {
#                 "self": "/vehicles/y1776"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "64",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "53316424",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 90,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 1,
#                 "direction_id": 1,
#                 "label": "1774",
#                 "latitude": 42.32993,
#                 "longitude": -71.08365,
#                 "occupancy_status": null,
#                 "speed": null,
#                 "updated_at": "2022-11-02T19:04:35-04:00"
#             },
#             "id": "y1774",
#             "links": {
#                 "self": "/vehicles/y1774"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "64",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "53315898",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         }
#     ],
#     "included": [
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-6",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "53314350",
#             "links": {
#                 "self": "/trips/53314350"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS422-hbc42wk1-Wdy-02",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010111",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-10",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "53314636",
#             "links": {
#                 "self": "/trips/53314636"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS422-hbc42wk1-Wdy-02",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010116",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-4",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "53314688",
#             "links": {
#                 "self": "/trips/53314688"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS422-hbc42wk1-Wdy-02",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010111",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-12",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "53314959",
#             "links": {
#                 "self": "/trips/53314959"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS422-hbc42wk1-Wdy-02",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010116",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-7",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "53315099",
#             "links": {
#                 "self": "/trips/53315099"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS422-hbc42wk1-Wdy-02",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010116",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-5",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "53315403",
#             "links": {
#                 "self": "/trips/53315403"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS422-hbc42wk1-Wdy-02",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010111",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-8",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "53315859",
#             "links": {
#                 "self": "/trips/53315859"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS422-hbc42wk1-Wdy-02",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010111",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-11",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "53315898",
#             "links": {
#                 "self": "/trips/53315898"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS422-hbc42wk1-Wdy-02",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010116",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-2",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "53316384",
#             "links": {
#                 "self": "/trips/53316384"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS422-hbc42wk1-Wdy-02",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010116",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-9",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "53316424",
#             "links": {
#                 "self": "/trips/53316424"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS422-hbc42wk1-Wdy-02",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010116",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         }
#     ],
#     "jsonapi": {
#         "version": "1.0"
#     }
# }
